# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishantsingh/Statistics-Part-2/blob/main/Statistics_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.  What is hypothesis testing in statistics ??
#
#   = Hypothesis testing is a formal method used to evaluate a claim or assumption about a population parameter based on sample data.

# %% [markdown]
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis ??
#
#   = The null hypothesis is a statement that assumes there is no effect, no difference, or no relationship between variables in the population, where as The alternative hypothesis represents the effect, difference, or relationship that the test aims to detect.

# %% [markdown]
# 3. What is the significance level in hypothesis testing, and why is it important ??
#
#   = The significance level (𝛼) is the threshold probability used in hypothesis testing to determine whether to reject the null hypothesis (
# 𝐻
# 0
# ​
#  ).
#
#  It is important because of the following reasons,
#
#  i. Controls the Risk of Type I Error
#
#  ii. Defines the Decision Rule
#
#  iii. Balances Confidence and Error etc.

# %% [markdown]
# 4. What does a P-value represent in hypothesis testing ??
#
#   = A P-value in hypothesis testing is a number that tells us how likely it is to get our sample results if the null hypothesis (
# 𝐻
# 0
# ​
#  ) is true.

# %% [markdown]
# 5. How do you interpret the P-value in hypothesis testing ??
#
#    = The key steps to interpret P-value in hypothesis testing are as follow,
#
#    i. Compare the P-value to the Significance Level
#
#    ii. Understand What the P-value Represents etc.

# %% [markdown]
# 6. What are Type 1 and Type 2 errors in hypothesis testing ??
#
#    = A Type I error occurs when the null hypothesis (
# 𝐻0
# ​ ) is rejected even though it is true, where as a Type II error occurs when the null hypothesis (
# 𝐻
# 0 ) is not rejected even though it is false.

# %% [markdown]
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing ??
#
#   = The major differences between a one-tailed and a two-tailed test in hypothesis testing are given below,
#
#  1. One-Tailed Test :
#
#    - One-tailed test examines whether the sample statistic is significantly greater than or less than a specified value in one direction.
#
#    - It is used when we have a directional hypothesis and are only interested in testing one direction of change.
#
#   2. Two-Tailed Test :
#
#    - A two-tailed test examines whether the sample statistic is significantly different from a specified value in either direction.
#
#    - It is used when we have a non-directional hypothesis and are interested in detecting any difference, regardless of direction.

# %% [markdown]
# 8. What is the Z-test, and when is it used in hypothesis testing ??
#
#   = A Z-test is a statistical test used in hypothesis testing to determine whether there is a significant difference between a sample statistic and a population parameter, assuming the data follows a normal distribution or the sample size is large.
#
#     It is used in the following conditions,
#
#     i. Population Variance is Known
#
#     ii. Large Sample Size
#
#     iii. Independent Observations
#
#     iv. Testing Means or Proportions etc.

# %% [markdown]
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing ??
#
#   = We calculate Z-score using the following formula,
#
#        Z-score =   X−μ / σ
#
#     Z-score represents the following things in hypothesis testing,
#
#       i. Distance from the Mean
#
#       ii. Significance in Hypothesis Testing etc.

# %% [markdown]
# 10. What is the T-distribution, and when should it be used instead of the normal distribution ??
#
#   = The T-distribution is a type of probability distribution that is used in hypothesis testing and confidence interval estimation when the sample size is small and the population standard deviation (
# 𝜎) is unknown.
#
# It should be used instead of the normal distribution in the following conditions,
#
#    i. When the sample size is less than 30
#
#    ii. Population standard deviation is unknown
#
#    iii. Data is normally distributed etc.

# %% [markdown]
# 11. What is the difference between a Z-test and a T-test ??
#
#   = The major differneces between a Z-test and a T-test are given below,
#
#     1. Z-Test :
#
#       - Its Population standard deviation is known,
#
#       - Its sample size is typically greater than 30,
#
#       - Degree of freedom is not applicable,
#
#       - It is used for hypothesis testing of means with large samples etc.
#
#     2. T-Testing :
#
#       - Its Population standard deviation is unknown,
#
#       - Its sample size is typically less than 30,
#
#       - Degree of freedon depends on sample size,
#
#       - It is used for hypothesis testing of means with small samples etc.

# %% [markdown]
# 12. What is the T-test, and how is it used in hypothesis testing ??
#
#    =  A T-test is a statistical test used in hypothesis testing to determine whether there is a significant difference between the means of two groups or between a sample mean and a population mean.
#
#    - The T-test is used when the population standard deviation is unknown, and it is ideal for small sample sizes.

# %% [markdown]
# 13. What is the relationship between Z-test and T-test in hypothesis testing ??
#
#  = The relationship between z-test and T-test can be shown with the help of following points,
#
#     - Both the Z-test and the T-test are used to test hypotheses about the population mean,
#
#     - Z-Test: The Z-test assumes that the population standard deviation is known and T-test assumes the population standard deviation is unknown,
#
#     - Z-test assumes sample size as large where as T-test assumes sample size as smaller etc.

# %% [markdown]
# 14. What is a confidence interval, and how is it used to interpret statistical results ??
#
#   =  A confidence interval (CI) is a range of values that is used to estimate a population parameter based on sample data. It is used to interpret statistical results on the basis of followings points,
#
#   i. Estimating Population Parameters
#
#   ii. Interpretation of Confidence Levels
#
#   iii. Decision Making in Hypothesis Testing
#
#   iv. Evaluating Precision and Uncertainty etc.

# %% [markdown]
# 15. What is the margin of error, and how does it affect the confidence interval ??
#
#    = The margin of error (MoE) is the amount by which the estimate of a population parameter is expected to differ from the true population value.
#
#      In the context of a confidence interval (CI), the margin of error represents half of the width of the interval. It is the amount added and subtracted from the point estimate to create the interval. It means if there is Larger Margin of Error tehre will be Wider Confidence Interval and if there is Smaller Margin of Error tehre will be Narrower Confidence Interval.

# %% [markdown]
# 16. How is Bayes' Theorem used in statistics, and what is its significance ??
#
#    =  Bayes' Theorem is a fundamental concept in probability theory and statistics that describes how to update the probability of a hypothesis based on new evidence or data.
#
#    Bayes' Theorem is used in statistics in the following ways,
#
#     i. Updating Beliefs
#
#     ii. Bayesian Classification
#
#     iii. Decision-Making
#
#     iv. Parameter Estimation etc.

# %% [markdown]
# 17. What is the Chi-square distribution, and when is it used ??
#
#    = The Chi-square distribution  is the distribution of a sum of the squares of independent standard normal random variables. The distribution is positively skewed and is characterized by a parameter called degrees of freedom (df), which affects the shape of the distribution.
#
#    It is used in the for following work,
#
#     i. Chi-Square Goodness of Fit Test
#
#     ii. Chi-Square Test of Independence
#
#     iii. Chi-Square Test for Homogeneity
#
#     iv. Confidence Intervals for Variance etc.

# %% [markdown]
# 18. What is the Chi-square goodness of fit test, and how is it applied ??
#
#   = The Chi-square goodness of fit test is a statistical test used to determine whether the observed frequencies in a categorical data set match the expected frequencies based on a specific hypothesis or distribution.
#
#   It is used when we have a single categorical variable and want to see if the data follows a particular expected distribution.

# %% [markdown]
# 19. What is the F-distribution, and when is it used in hypothesis testing ??
#
#   = F-distribution is the ratio of two independent Chi-square distributed variables, each divided by their respective degrees of freedom.
#
#   It is used to test hypotheses about variances, and it is the basis for several important statistical tests, such as the ANOVA test and regression analysis.

# %% [markdown]
# 20. What is an ANOVA test, and what are its assumptions ??
#
#   = ANOVA is a statistical method used to compare the means of three or more groups to determine if there is a significant difference between them.
#
#    The assumptions of ANOVA are as follow,
#
#     - Independence
#
#     - Normality
#
#     - Homogeneity of Variances
#
#     - Random Sampling etc.

# %% [markdown]
# 21. What are the different types of ANOVA tests ??
#
#   =  The different types of ANOVA tests are as follow,
#
#     i. One-Way ANOVA
#
#     ii. Two-way ANOVA
#
#     iii. Repeated Measures ANOVA
#
#     iv. Multivariate Analysis of Variance (MANOVA)
#
#     v.  Mixed-Design ANOVA
#
#     vi. Analysis of Covariance (ANCOVA) etc.

# %% [markdown]
# 22. What is the F-test, and how does it relate to hypothesis testing ??
#
#   = The F-test is a statistical test used to compare the variances of two or more groups to determine if there is a significant difference between them.
#
#   The F-test is an essential tool in hypothesis testing for comparing variances and assessing the overall fit of models. It is particularly useful in ANOVA and regression analysis.

# %%
# Practical Questions

# %% [markdown]
# 1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results.

# %%
import numpy as np
from scipy import stats

def z_test(sample_data, population_mean, population_std, sample_size, significance_level=0.05):
    sample_mean = np.mean(sample_data)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    print(f"Sample Mean: {sample_mean}")
    print(f"Z-score: {z_score}")
    print(f"P-value: {p_value}")

    if p_value < significance_level:
        print("Reject the null hypothesis: There is a significant difference between the sample mean and population mean.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference between the sample mean and population mean.")

# %%
if __name__ == "__main__":
    sample_data = [85, 88, 91, 83, 79, 94, 88, 82, 91, 87,
                   84, 79, 90, 93, 86, 89, 84, 80, 95, 87,
                   82, 88, 90, 91, 85, 83, 92, 87, 86, 90]

    population_mean = 85
    population_std = 5
    sample_size = len(sample_data)
    z_test(sample_data, population_mean, population_std, sample_size)
# Out:
# Sample Mean: 86.96666666666667
# Z-score: 2.1543753928536553
# P-value: 0.031210744716718697
# Reject the null hypothesis: There is a significant difference between the sample mean and population mean.

# %% [markdown]
# 2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.

# %%
import numpy as np
from scipy import stats

def simulate_and_test(population_mean, population_std, sample_size, significance_level=0.05):
    sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
    sample_mean = np.mean(sample_data)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < significance_level:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

# %%
if __name__ == "__main__":
    population_mean = 100
    population_std = 15
    sample_size = 50
    significance_level = 0.05

    simulate_and_test(population_mean, population_std, sample_size, significance_level)
# Out:
# Sample Mean: 98.63
# Z-score: -0.65
# P-value: 0.5177
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %% [markdown]
# 3.  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.

# %%
import numpy as np
from scipy import stats

def one_sample_z_test(sample_data, population_mean, population_std, significance_level=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < significance_level:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

# %%
if __name__ == "__main__":
    sample_data = np.random.normal(loc=102, scale=15, size=50)  # Mean=102, Std=15, Size=50
    population_mean = 100
    population_std = 15
    one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 103.22
# Z-score: 1.52
# P-value: 0.1287
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %% [markdown]
# 4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def two_tailed_z_test(sample_data, population_mean, population_std, significance_level=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < significance_level:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

    plot_decision_region(z_score, significance_level)

def plot_decision_region(z_score, significance_level):
    critical_value = stats.norm.ppf(1 - significance_level / 2)
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x)

    plt.plot(x, y, label='Standard Normal Distribution')
    plt.fill_between(x, y, where=(x <= -critical_value) | (x >= critical_value), color='red', alpha=0.3, label='Rejection Region')
    plt.axvline(z_score, color='blue', linestyle='dashed', label=f'Z-score: {z_score:.2f}')

    plt.axvline(critical_value, color='green', linestyle='dashed', label=f'Critical Z-value: ±{critical_value:.2f}')
    plt.axvline(-critical_value, color='green', linestyle='dashed')
    plt.title('Two-Tailed Z-Test with Decision Region')
    plt.xlabel('Z-Score')
    plt.ylabel('Probability Density')
    plt.legend(loc='best')
    plt.show()

# %%
if __name__ == "__main__":
    sample_data = np.random.normal(loc=102, scale=15, size=50)
    population_mean = 100
    population_std = 15

    two_tailed_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 102.54
# Z-score: 1.20
# P-value: 0.2310
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %% [markdown]
# 5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def visualize_type_errors(population_mean, population_std, sample_size, alternative_mean, significance_level=0.05):
    critical_value = stats.norm.ppf(1 - significance_level / 2)
    null_distribution = np.random.normal(loc=population_mean, scale=population_std, size=10000)
    alternative_distribution = np.random.normal(loc=alternative_mean, scale=population_std, size=10000)
    sample_means_null = np.random.normal(loc=population_mean, scale=population_std/np.sqrt(sample_size), size=10000)
    sample_means_alt = np.random.normal(loc=alternative_mean, scale=population_std/np.sqrt(sample_size), size=10000)

    plt.figure(figsize=(10, 6))
    plt.hist(sample_means_null, bins=30, alpha=0.5, label='Null Hypothesis (H₀)', color='blue', density=True)
    plt.hist(sample_means_alt, bins=30, alpha=0.5, label='Alternative Hypothesis (H₁)', color='red', density=True)
    plt.axvline(x=-critical_value, color='green', linestyle='dashed', label=f'Critical Z-value: ±{critical_value:.2f}')
    plt.axvline(x=critical_value, color='green', linestyle='dashed')
    plt.fill_betweenx(np.linspace(0, 0.03, 100), critical_value, 4, color='green', alpha=0.3, label='Type I Error Region')
    plt.fill_betweenx(np.linspace(0, 0.03, 100), -4, -critical_value, color='green', alpha=0.3)
    plt.fill_betweenx(np.linspace(0, 0.03, 100), -critical_value, critical_value, color='red', alpha=0.3, label='Type II Error Region')
    plt.title('Visualization of Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Sample Mean')
    plt.ylabel('Density')
    plt.legend(loc='best')
    plt.show()

# %%
if __name__ == "__main__":
    population_mean = 100
    population_std = 15
    sample_size = 30
    alternative_mean = 105

    visualize_type_errors(population_mean, population_std, sample_size, alternative_mean)

# %% [markdown]
# 6.  Write a Python program to perform an independent T-test and interpret the results.

# %%
import numpy as np
from scipy import stats

def independent_t_test(sample1, sample2, significance_level=0.05):
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)

    print(f"T-statistic: {t_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < significance_level:
        print("Reject the null hypothesis: There is a significant difference between the means of the two samples.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference between the means of the two samples.")

# %%
if __name__ == "__main__":
    np.random.seed(0)
    sample1 = np.random.normal(loc=100, scale=15, size=50)
    sample2 = np.random.normal(loc=105, scale=15, size=50)
    independent_t_test(sample1, sample2)
# Out:
# T-statistic: -0.8466
# P-value: 0.3993
# Fail to reject the null hypothesis: There is no significant difference between the means of the two samples.

# %% [markdown]
# 7. Perform a paired sample T-test using Python and visualize the comparison results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def paired_sample_t_test(before, after, significance_level=0.05):
    t_statistic, p_value = stats.ttest_rel(before, after)

    print(f"T-statistic: {t_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < significance_level:
        print("Reject the null hypothesis: There is a significant difference between the before and after measurements.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference between the before and after measurements.")

    visualize_comparison(before, after)

def visualize_comparison(before, after):
    plt.figure(figsize=(8, 6))
    labels = ['Before', 'After']
    means = [np.mean(before), np.mean(after)]
    stds = [np.std(before), np.std(after)]

    plt.bar(labels, means, yerr=stds, capsize=10, color=['blue', 'orange'], alpha=0.7)
    plt.scatter(['Before'] * len(before), before, color='blue', alpha=0.6, label='Before measurements')
    plt.scatter(['After'] * len(after), after, color='orange', alpha=0.6, label='After measurements')
    plt.title('Comparison of Before and After Measurements (Paired Sample T-test)')
    plt.ylabel('Measurement Value')
    plt.legend()
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(0)
    before = np.random.normal(loc=80, scale=10, size=30)
    after = before + np.random.normal(loc=5, scale=5, size=30)

    paired_sample_t_test(before, after)
# Out:
# T-statistic: -4.2565
# P-value: 0.0002
# Reject the null hypothesis: There is a significant difference between the before and after measurements.

# %% [markdown]
# 8. Simulate data and perform both Z-test and T-test, then compare the results using Python.

# %%
import numpy as np
from scipy import stats

def z_test(sample_data, population_mean, population_std, significance_level=0.05):
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    return z_score, p_value

def t_test(sample_data, population_mean, significance_level=0.05):
    t_statistic, p_value = stats.ttest_1samp(sample_data, population_mean)

    return t_statistic, p_value

np.random.seed(0)
population_mean = 100
population_std = 15
sample_size = 50

sample_data = np.random.normal(loc=100, scale=15, size=sample_size)
z_score, z_p_value = z_test(sample_data, population_mean, population_std)
t_statistic, t_p_value = t_test(sample_data, population_mean)
print("Z-test Results:")
print(f"Z-score: {z_score:.4f}")
print(f"P-value: {z_p_value:.4f}")
print("\nT-test Results:")
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {t_p_value:.4f}")

significance_level = 0.05
if z_p_value < significance_level:
    print("\nZ-test: Reject the null hypothesis - The sample mean is significantly different from the population mean.")
else:
    print("\nZ-test: Fail to reject the null hypothesis - The sample mean is not significantly different from the population mean.")

if t_p_value < significance_level:
    print("T-test: Reject the null hypothesis - The sample mean is significantly different from the population mean.")
else:
    print("T-test: Fail to reject the null hypothesis - The sample mean is not significantly different from the population mean.")
# Out:
# Z-test Results:
# Z-score: 0.9939
# P-value: 0.3203
#
# T-test Results:
# T-statistic: 0.8742
# P-value: 0.3863
#
# Z-test: Fail to reject the null hypothesis - The sample mean is not significantly different from the population mean.
# T-test: Fail to reject the null hypothesis - The sample mean is not significantly different from the population mean.

# %% [markdown]
# 9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.

# %%
import numpy as np
from scipy import stats

def confidence_interval(sample_data, confidence_level=0.95):
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)
    sample_size = len(sample_data)
    z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    margin_of_error = z_score * (sample_std / np.sqrt(sample_size))

    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# %%
if __name__ == "__main__":
    np.random.seed(0)
    sample_data = np.random.normal(loc=75, scale=10, size=50)
    lower_bound, upper_bound = confidence_interval(sample_data, confidence_level=0.95)
    print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# %% [markdown]
# 10. Write a Python program to calculate the margin of error for a given confidence level using sample data.

# %%
import math
from scipy.stats import norm

def calculate_margin_of_error(confidence_level, sample_std_dev, sample_size):
    z_score = norm.ppf(1 - (1 - confidence_level) / 2)
    standard_error = sample_std_dev / math.sqrt(sample_size)
    margin_of_error = z_score * standard_error

    return margin_of_error

if __name__ == "__main__":
    confidence_level = 0.95
    sample_std_dev = 12.5
    sample_size = 100

    margin_of_error = calculate_margin_of_error(confidence_level, sample_std_dev, sample_size)
    print(f"Margin of Error: {margin_of_error:.2f}")
# Out:
# Margin of Error: 2.45

# %% [markdown]
# 11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.

# %%
def bayesian_inference(prior, likelihood_given_h, likelihood_given_not_h):
    prior_not_h = 1 - prior
    numerator = likelihood_given_h * prior
    denominator = (likelihood_given_h * prior) + (likelihood_given_not_h * prior_not_h)
    posterior = numerator / denominator

    return posterior

if __name__ == "__main__":
    prior = 0.01
    likelihood_given_h = 0.95
    likelihood_given_not_h = 0.05

    posterior = bayesian_inference(prior, likelihood_given_h, likelihood_given_not_h)
    print(f"Posterior Probability (P(H|E)): {posterior:.4f}")
# Out:
# Posterior Probability (P(H|E)): 0.1610

# %% [markdown]
# 12. Perform a Chi-square test for independence between two categorical variables in Python.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
data = np.array([[30, 20],
                 [20, 30]])

contingency_table = pd.DataFrame(data, columns=["Product A", "Product B"], index=["Male", "Female"])
print("Contingency Table:")
print(contingency_table)

chi2, p, dof, expected = chi2_contingency(data)

print("\nChi-square Test Results:")
print(f"Chi-square Statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of Freedom: {dof}")
print("\nExpected Frequencies:")
print(expected)

alpha = 0.05
if p < alpha:
    print("\nConclusion: There is a significant association between Gender and Preference.")
else:
    print("\nConclusion: There is no significant association between Gender and Preference.")
# Out:
# Contingency Table:
#         Product A  Product B
# Male           30         20
# Female         20         30
#
# Chi-square Test Results:
# Chi-square Statistic: 3.2400
# P-value: 0.0719
# Degrees of Freedom: 1
#
# Expected Frequencies:
# [[25. 25.]
#  [25. 25.]]
#
# Conclusion: There is no significant association between Gender and Preference.

# %% [markdown]
# 13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data.

# %%
import numpy as np
import pandas as pd

def calculate_expected_frequencies(observed):
    observed = np.array(observed)
    row_totals = observed.sum(axis=1)
    col_totals = observed.sum(axis=0)
    total = observed.sum()
    expected = np.outer(row_totals, col_totals) / total
    return expected

observed_data = np.array([[50, 30, 20],  # Row 1
                          [30, 40, 30],  # Row 2
                          [20, 30, 50]]) # Row 3

observed_df = pd.DataFrame(observed_data, columns=["Category A", "Category B", "Category C"],
                           index=["Group 1", "Group 2", "Group 3"])
print("Observed Frequencies:")
print(observed_df)

expected_frequencies = calculate_expected_frequencies(observed_data)

expected_df = pd.DataFrame(expected_frequencies, columns=["Category A", "Category B", "Category C"],
                           index=["Group 1", "Group 2", "Group 3"])
print("\nExpected Frequencies:")
print(expected_df)
# Out:
# Observed Frequencies:
#          Category A  Category B  Category C
# Group 1          50          30          20
# Group 2          30          40          30
# Group 3          20          30          50
#
# Expected Frequencies:
#          Category A  Category B  Category C
# Group 1   33.333333   33.333333   33.333333
# Group 2   33.333333   33.333333   33.333333
# Group 3   33.333333   33.333333   33.333333

# %% [markdown]
# 14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.

# %%
import numpy as np
from scipy.stats import chisquare
observed = np.array([50, 30, 20])
expected_proportions = np.array([0.4, 0.4, 0.2])
total = observed.sum()
expected = expected_proportions * total
chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

print("Observed Frequencies:", observed)
print("Expected Frequencies:", expected)
print(f"\nChi-square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("\nConclusion: The observed data significantly differ from the expected distribution.")
else:
    print("\nConclusion: The observed data do not significantly differ from the expected distribution.")
# Out:
# Observed Frequencies: [50 30 20]
# Expected Frequencies: [40. 40. 20.]
#
# Chi-square Statistic: 5.0000
# P-value: 0.0821
#
# Conclusion: The observed data do not significantly differ from the expected distribution.

# %% [markdown]
# 15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

def simulate_chi_square(df_values, num_samples=1000):
    x = np.linspace(0, 20, 1000)
    plt.figure(figsize=(10, 6))
    for df in df_values:
        samples = np.random.chisquare(df, num_samples)
        pdf = chi2.pdf(x, df)
        plt.plot(x, pdf, label=f'df={df}')
        plt.hist(samples, bins=30, density=True, alpha=0.3, label=f'Samples (df={df})')

    plt.title('Chi-square Distribution')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()
df_values = [1, 2, 5, 10]
simulate_chi_square(df_values)

# %% [markdown]
# 16. Implement an F-test using Python to compare the variances of two random samples.

# %%
import numpy as np
from scipy.stats import f

def f_test(sample1, sample2, alpha=0.05):
    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)
    f_stat = var1 / var2 if var1 > var2 else var2 / var1
    df1 = len(sample1) - 1
    df2 = len(sample2) - 1
    p_value = 2 * min(f.cdf(f_stat, df1, df2), 1 - f.cdf(f_stat, df1, df2))
    conclusion = "Fail to reject H0: Variances are equal"
    if p_value < alpha:
        conclusion = "Reject H0: Variances are significantly different"

    return {
        "F-statistic": f_stat,
        "p-value": p_value,
        "Conclusion": conclusion,
        "Degrees of Freedom": (df1, df2),
    }

# %%
if __name__ == "__main__":
    np.random.seed(42)
    sample1 = np.random.normal(10, 5, 30)
    sample2 = np.random.normal(12, 8, 40)

    result = f_test(sample1, sample2)

    print("F-test Results:")
    print(f"F-statistic: {result['F-statistic']:.4f}")
    print(f"P-value: {result['p-value']:.4f}")
    print(f"Degrees of Freedom: {result['Degrees of Freedom']}")
    print(f"Conclusion: {result['Conclusion']}")
# Out:
# F-test Results:
# F-statistic: 2.6095
# P-value: 0.0055
# Degrees of Freedom: (29, 39)
# Conclusion: Reject H0: Variances are significantly different

# %% [markdown]
# 17. Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results.

# %%
import numpy as np
from scipy.stats import f_oneway

def perform_anova(*groups):
    f_stat, p_value = f_oneway(*groups)
    alpha = 0.05
    conclusion = "Fail to reject H0: No significant difference between group means"
    if p_value < alpha:
        conclusion = "Reject H0: Significant difference between group means"

    return {
        "F-statistic": f_stat,
        "p-value": p_value,
        "Conclusion": conclusion,
    }

# %%
if __name__ == "__main__":
    group1 = np.random.normal(50, 5, 30)
    group2 = np.random.normal(55, 5, 30)
    group3 = np.random.normal(60, 5, 30)

    result = perform_anova(group1, group2, group3)

    print("ANOVA Test Results:")
    print(f"F-statistic: {result['F-statistic']:.4f}")
    print(f"P-value: {result['p-value']:.4f}")
    print(f"Conclusion: {result['Conclusion']}")
# Out:
# ANOVA Test Results:
# F-statistic: 30.5200
# P-value: 0.0000
# Conclusion: Reject H0: Significant difference between group means

# %% [markdown]
# 18.  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

def perform_anova_and_plot(groups, group_labels):
    f_stat, p_value = f_oneway(*groups)
    alpha = 0.05
    conclusion = "Fail to reject H0: No significant difference between group means"
    if p_value < alpha:
        conclusion = "Reject H0: Significant difference between group means"

    print("ANOVA Test Results:")
    print(f"F-statistic: {f_stat:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Conclusion: {conclusion}")

    plt.figure(figsize=(10, 6))
    plt.boxplot(groups, labels=group_labels, patch_artist=True, boxprops=dict(facecolor="skyblue"))
    plt.title("Group Distributions")
    plt.xlabel("Groups")
    plt.ylabel("Values")
    plt.grid(alpha=0.3)
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    group1 = np.random.normal(50, 5, 30)
    group2 = np.random.normal(55, 5, 30)
    group3 = np.random.normal(60, 5, 30)

    perform_anova_and_plot([group1, group2, group3], group_labels=["Group 1", "Group 2", "Group 3"])
# Out:
# ANOVA Test Results:
# F-statistic: 40.9756
# P-value: 0.0000
# Conclusion: Reject H0: Significant difference between group means
# <ipython-input-12-e44b72472da6>:18: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=group_labels, patch_artist=True, boxprops=dict(facecolor="skyblue"))

# %% [markdown]
# 19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import normaltest, levene, shapiro

def check_anova_assumptions(groups, group_labels):
    print("\nNormality Test Results:")
    for i, group in enumerate(groups):
        stat, p_value = normaltest(group)
        print(f"Group {group_labels[i]} (D'Agostino's test): p-value = {p_value:.4f}")

        stat, p_value_shapiro = shapiro(group)
        print(f"Group {group_labels[i]} (Shapiro-Wilk test): p-value = {p_value_shapiro:.4f}")

    print("\nEqual Variance Test (Levene's test):")
    stat, p_value_levene = levene(*groups)
    print(f"Levene's test p-value: {p_value_levene:.4f}")

    print("\nVisualizing the data distributions:")
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.boxplot(data=groups)
    plt.xticks(range(1, len(group_labels) + 1), group_labels)
    plt.title("Boxplots for Equal Variance")

    plt.subplot(1, 2, 2)
    for i, group in enumerate(groups):
        sns.histplot(group, kde=True, label=group_labels[i], bins=15)
    plt.legend()
    plt.title("Histograms for Normality Check")
    plt.tight_layout()
    plt.show()

    alpha = 0.05
    print("\nAssumptions Check Conclusion:")

    normality_ok = all(p > alpha for group in groups for p in [normaltest(group)[1], shapiro(group)[1]])
    if normality_ok:
        print("Normality: All groups passed normality assumption.")
    else:
        print("Normality: One or more groups failed normality assumption.")

    if p_value_levene > alpha:
        print("Equal Variance: Groups passed the equal variance assumption.")
    else:
        print("Equal Variance: Groups failed the equal variance assumption.")

    print("Independence: Assumed to be satisfied based on study design (this should be checked in data collection).")

# %%
if __name__ == "__main__":
    np.random.seed(42)
    group1 = np.random.normal(50, 5, 30)
    group2 = np.random.normal(55, 5, 30)
    group3 = np.random.normal(60, 5, 30)

    check_anova_assumptions([group1, group2, group3], group_labels=["Group 1", "Group 2", "Group 3"])
# Out:
# Normality Test Results:
# Group Group 1 (D'Agostino's test): p-value = 0.9260
# Group Group 1 (Shapiro-Wilk test): p-value = 0.6868
# Group Group 2 (D'Agostino's test): p-value = 0.8353
# Group Group 2 (Shapiro-Wilk test): p-value = 0.9130
# Group Group 3 (D'Agostino's test): p-value = 0.2594
# Group Group 3 (Shapiro-Wilk test): p-value = 0.3654
#
# Equal Variance Test (Levene's test):
# Levene's test p-value: 0.8627
#
# Visualizing the data distributions:
# Assumptions Check Conclusion:
# Normality: All groups passed normality assumption.
# Equal Variance: Groups passed the equal variance assumption.
# Independence: Assumed to be satisfied based on study design (this should be checked in data collection).

# %% [markdown]
# 20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

def perform_two_way_anova(data, formula):
    model = ols(formula, data=data).fit()
    anova_table = anova_lm(model)
    print("\nTwo-Way ANOVA Results:")
    print(anova_table)

    if anova_table["PR(>F)"]["factor1"] < 0.05:
        print("Factor 1 is significant.")
    if anova_table["PR(>F)"]["factor2"] < 0.05:
        print("Factor 2 is significant.")
    if anova_table["PR(>F)"]["factor1:factor2"] < 0.05:
        print("The interaction between Factor 1 and Factor 2 is significant.")

    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.catplot(x='factor1', y='dependent', hue='factor2', kind='point', data=data, markers=["o", "s"], linestyles=["-", "--"])
    plt.title("Interaction Plot between Factor 1 and Factor 2")
    plt.xlabel("Factor 1")
    plt.ylabel("Dependent Variable")
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    factor1 = np.repeat(["A", "B"], 50)
    factor2 = np.tile(["X", "Y"], 50)
    dependent = np.random.normal(10, 5, 100) + np.where(factor1 == "A", 2, 0) + np.where(factor2 == "X", 3, 0)

    data = pd.DataFrame({
        'factor1': factor1,
        'factor2': factor2,
        'dependent': dependent
    })

    formula = 'dependent ~ factor1 * factor2'
    perform_two_way_anova(data, formula)
# Out:
# Two-Way ANOVA Results:
#                    df       sum_sq     mean_sq         F    PR(>F)
# factor1           1.0    15.355666   15.355666  0.741980  0.391174
# factor2           1.0   179.789061  179.789061  8.687344  0.004023
# factor1:factor2   1.0    15.020139   15.020139  0.725768  0.396379
# Residual         96.0  1986.769563   20.695516       NaN       NaN
# Factor 2 is significant.

# %% [markdown]
# 21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

def plot_f_distribution(df1, df2, x_range=(0, 5), num_points=1000):
    x = np.linspace(x_range[0], x_range[1], num_points)
    pdf = f.pdf(x, df1, df2)

    plt.figure(figsize=(10, 6))
    plt.plot(x, pdf, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')
    plt.fill_between(x, pdf, color='skyblue', alpha=0.5)
    plt.title(f"F-distribution (df1={df1}, df2={df2})")
    plt.xlabel("F-value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    plot_f_distribution(df1=5, df2=10)

# %% [markdown]
# 22.  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

def perform_one_way_anova(groups, group_labels):
    f_statistic, p_value = f_oneway(*groups)

    print(f"One-Way ANOVA Results:")
    print(f"F-statistic: {f_statistic:.4f}, p-value: {p_value:.4f}")

    alpha = 0.05
    if p_value < alpha:
        print(f"The p-value is less than {alpha}. We reject the null hypothesis.")
    else:
        print(f"The p-value is greater than {alpha}. We fail to reject the null hypothesis.")

    plt.figure(figsize=(8, 6))
    sns.boxplot(data=groups, palette="Set2")
    plt.xticks(range(len(group_labels)), group_labels)
    plt.title("Boxplots for One-Way ANOVA")
    plt.xlabel("Group")
    plt.ylabel("Values")
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    group1 = np.random.normal(50, 5, 30)
    group2 = np.random.normal(55, 5, 30)
    group3 = np.random.normal(60, 5, 30)
    group_labels = ["Group 1", "Group 2", "Group 3"]

    perform_one_way_anova([group1, group2, group3], group_labels)
# Out:
# One-Way ANOVA Results:
# F-statistic: 40.9756, p-value: 0.0000
# The p-value is less than 0.05. We reject the null hypothesis.

# %% [markdown]
# 23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

def perform_hypothesis_testing(sample_data, population_mean):
    t_statistic, p_value = stats.ttest_1samp(sample_data, population_mean)

    print(f"One-Sample t-Test Results:")
    print(f"t-statistic: {t_statistic:.4f}, p-value: {p_value:.4f}")

    alpha = 0.05
    if p_value < alpha:
        print(f"Since the p-value is less than {alpha}, we reject the null hypothesis.")
    else:
        print(f"Since the p-value is greater than {alpha}, we fail to reject the null hypothesis.")

    plt.figure(figsize=(8, 6))
    plt.hist(sample_data, bins=20, alpha=0.7, color='skyblue', edgecolor='black', label='Sample Data')
    plt.axvline(population_mean, color='red', linestyle='dashed', linewidth=2, label=f'Population Mean = {population_mean}')
    plt.title("Sample Data Distribution and Population Mean")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    sample_data = np.random.normal(loc=55, scale=10, size=100)
    population_mean = 50

    perform_hypothesis_testing(sample_data, population_mean)
# Out:
# One-Sample t-Test Results:
# t-statistic: 4.3621, p-value: 0.0000
# Since the p-value is less than 0.05, we reject the null hypothesis.

# %% [markdown]
# 24.  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.

# %%
import numpy as np
from scipy.stats import chi2
import matplotlib.pyplot as plt

def perform_chi_square_variance_test(sample_data, population_variance, alpha=0.05):
    n = len(sample_data)
    sample_variance = np.var(sample_data, ddof=1)
    chi_square_statistic = (n - 1) * sample_variance / population_variance

    df = n - 1

    chi_square_lower = chi2.ppf(alpha / 2, df)
    chi_square_upper = chi2.ppf(1 - alpha / 2, df)

    print(f"Chi-Square Test Results:")
    print(f"Chi-Square Statistic: {chi_square_statistic:.4f}")
    print(f"Critical Values: Lower = {chi_square_lower:.4f}, Upper = {chi_square_upper:.4f}")

    if chi_square_statistic < chi_square_lower or chi_square_statistic > chi_square_upper:
        print(f"Since the Chi-square statistic is outside the critical values, we reject the null hypothesis.")
    else:
        print(f"Since the Chi-square statistic is within the critical values, we fail to reject the null hypothesis.")

    x = np.linspace(0, chi_square_upper + 5, 500)
    y = chi2.pdf(x, df)

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f'Chi-square Distribution (df={df})', color='blue')
    plt.fill_between(x, y, where=(x <= chi_square_lower) | (x >= chi_square_upper), color='red', alpha=0.5, label='Rejection Region')
    plt.axvline(chi_square_statistic, color='green', linestyle='dashed', linewidth=2, label=f'Statistic = {chi_square_statistic:.4f}')
    plt.axvline(chi_square_lower, color='black', linestyle='dashed', label=f'Critical Lower = {chi_square_lower:.4f}')
    plt.axvline(chi_square_upper, color='black', linestyle='dashed', label=f'Critical Upper = {chi_square_upper:.4f}')

    plt.title("Chi-Square Test for Population Variance")
    plt.xlabel("Chi-Square Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    sample_data = np.random.normal(loc=50, scale=10, size=30)
    population_variance = 100
    perform_chi_square_variance_test(sample_data, population_variance, alpha=0.05)
# Out:
# Chi-Square Test Results:
# Chi-Square Statistic: 23.4903
# Critical Values: Lower = 16.0471, Upper = 45.7223
# Since the Chi-square statistic is within the critical values, we fail to reject the null hypothesis.

# %% [markdown]
# 25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

def perform_z_test_for_proportions(successes1, n1, successes2, n2, alpha=0.05):
    p1 = successes1 / n1
    p2 = successes2 / n2

    pooled_p = (successes1 + successes2) / (n1 + n2)
    z_statistic = (p1 - p2) / np.sqrt(pooled_p * (1 - pooled_p) * (1/n1 + 1/n2))

    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

    print(f"Z-statistic: {z_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Since the p-value is less than {alpha}, we reject the null hypothesis.")
    else:
        print(f"Since the p-value is greater than {alpha}, we fail to reject the null hypothesis.")

    z_values = np.linspace(-4, 4, 1000)
    pdf_values = stats.norm.pdf(z_values, loc=0, scale=1)

    plt.figure(figsize=(8, 6))
    plt.plot(z_values, pdf_values, label="Standard Normal Distribution")
    plt.fill_between(z_values, pdf_values, where=(z_values >= abs(z_statistic)), color='red', alpha=0.5, label="Rejection Region")
    plt.axvline(z_statistic, color='green', linestyle='dashed', label=f'Z-statistic = {z_statistic:.4f}')
    plt.title("Z-test for Comparing Proportions")
    plt.xlabel("Z-value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    successes1 = 120
    n1 = 200
    successes2 = 100
    n2 = 180

    perform_z_test_for_proportions(successes1, n1, successes2, n2, alpha=0.05)
# Out:
# Z-statistic: 0.8762
# P-value: 0.3809
# Since the p-value is greater than 0.05, we fail to reject the null hypothesis.

# %% [markdown]
# 26.  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

def perform_f_test(data1, data2, alpha=0.05):
    n1 = len(data1)
    n2 = len(data2)
    var1 = np.var(data1, ddof=1)
    var2 = np.var(data2, ddof=1)
    f_statistic = var1 / var2 if var1 >= var2 else var2 / var1
    df1 = n1 - 1
    df2 = n2 - 1
    p_value = 2 * min(stats.f.cdf(f_statistic, df1, df2), 1 - stats.f.cdf(f_statistic, df1, df2))

    print(f"F-statistic: {f_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < alpha:
        print(f"Since the p-value is less than {alpha}, we reject the null hypothesis.")
    else:
        print(f"Since the p-value is greater than {alpha}, we fail to reject the null hypothesis.")

    x = np.linspace(0, 5, 1000)
    y = stats.f.pdf(x, df1, df2)

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')
    plt.fill_between(x, y, where=(x >= f_statistic), color='red', alpha=0.5, label='Rejection Region')
    plt.axvline(f_statistic, color='green', linestyle='dashed', linewidth=2, label=f'F-statistic = {f_statistic:.4f}')
    plt.title("F-test for Comparing Variances")
    plt.xlabel("F-value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
if __name__ == "__main__":
    np.random.seed(42)
    data1 = np.random.normal(loc=50, scale=10, size=100)
    data2 = np.random.normal(loc=50, scale=20, size=100)

    perform_f_test(data1, data2, alpha=0.05)
# Out:
# F-statistic: 4.4109
# P-value: 0.0000
# Since the p-value is less than 0.05, we reject the null hypothesis.

# %% [markdown]
# 27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
from scipy.stats import chisquare
observed_data = np.array([15, 25, 10, 20, 30, 40])
expected_data_adjusted = np.array([140/6] * 6)
chi2_stat, p_value = chisquare(observed_data, expected_data_adjusted)

print(f"Chi-square statistic: {chi2_stat}")
print(f"p-value: {p_value}")

if p_value < 0.05:
    print("We reject the null hypothesis. There is a significant difference between the observed and expected frequencies.")
else:
    print("We fail to reject the null hypothesis. There is no significant difference between the observed and expected frequencies.")
# Out:
# Chi-square statistic: 25.0
# p-value: 0.0001393337911856263
# We reject the null hypothesis. There is a significant difference between the observed and expected frequencies.
